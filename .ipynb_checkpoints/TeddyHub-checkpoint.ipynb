# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.ensemble import IsolationForest

# %%
data_train=pd.read_csv("C:/Users/Lenovo/Desktop/Teddy_Git/order_train1.csv")
data_train
# Out:
#         order_date  sales_region_code  item_code  first_cate_code  \
# 0       2015/11/12                105      22084              306
# 1       2015/11/12                101      22084              306
# 2       2017/10/21                101      22084              306
# 3       2017/10/23                101      22084              306
# 4       2015/10/24                101      22084              305
# ...            ...                ...        ...              ...
# 597689  2018/12/20                102      20001              306
# 597690  2018/12/20                102      20001              306
# 597691  2018/12/20                102      20001              306
# 597692  2018/12/20                102      20001              302
# 597693  2018/12/20                102      20001              302
#
#         second_cate_code sales_chan_name  item_price  ord_qty  597695  \
# 0                    402          online     2764.00    16308     NaN
# 1                    402         offline     2762.00    16301     NaN
# 2                    407         offline      815.00    12481     NaN
# 3                    407         offline      813.00    12480     NaN
# 4                    412         offline     3005.00    10825     NaN
# ...                  ...             ...         ...      ...     ...
# 597689               407         offline        7.01        1     NaN
# 597690               407         offline        7.01        1     NaN
# 597691               407         offline        7.01        1     NaN
# 597692               408         offline        7.01        1     NaN
# 597693               408         offline        6.01        1     NaN
#
#         597695.1  597695.2  597695.3  597695.4  597695.5  597695.6
# 0            NaN       NaN       NaN       NaN       NaN       NaN
# 1            NaN       NaN       NaN       NaN       NaN       NaN
# 2            NaN       NaN       NaN       NaN       NaN       NaN
# 3            NaN       NaN       NaN       NaN       NaN       NaN
# 4            NaN       NaN       NaN       NaN       NaN       NaN
# ...          ...       ...       ...       ...       ...       ...
# 597689       NaN       NaN       NaN       NaN       NaN       NaN
# 597690       NaN       NaN       NaN       NaN       NaN       NaN
# 597691       NaN       NaN       NaN       NaN       NaN       NaN
# 597692       NaN       NaN       NaN       NaN       NaN       NaN
# 597693       NaN       NaN       NaN       NaN       NaN       NaN
#
# [597694 rows x 15 columns]

# %% [markdown]
# ## 箱线图

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
group=data_train.groupby("item_code")

# %%
describe=group.describe()

# %%
describe["sales_region_code"]["count"]
# Out:
# item_code
# 20001      13.0
# 20002     694.0
# 20003    2767.0
# 20005      20.0
# 20006    1523.0
#           ...
# 22080    1724.0
# 22081    1269.0
# 22082     159.0
# 22083     311.0
# 22084     468.0
# Name: count, Length: 1758, dtype: float64

# %%
describe1=describe[describe["sales_region_code"]["count"]<=50]

# %%
describe1[describe1["sales_region_code"]["count"]>=40]
# Out:
#           sales_region_code                                              \
#                       count        mean       std    min     25%    50%
# item_code
# 20098                  49.0  102.714286  1.399405  101.0  102.00  103.0
# 20105                  49.0  102.714286  1.322876  101.0  101.00  103.0
# 20218                  50.0  102.960000  1.564400  101.0  101.00  103.0
# 20429                  43.0  103.511628  1.594217  101.0  102.00  103.0
# 20520                  45.0  102.333333  1.296849  101.0  101.00  102.0
# 20572                  44.0  102.818182  1.846086  101.0  101.00  102.0
# 20594                  42.0  102.928571  1.368511  101.0  102.00  103.0
# 20603                  45.0  102.688889  1.489695  101.0  102.00  102.0
# 20607                  50.0  102.840000  1.595402  101.0  101.00  103.0
# 20639                  43.0  103.069767  1.579562  101.0  102.00  103.0
# 20680                  46.0  102.695652  1.297340  101.0  102.00  102.0
# 20711                  49.0  102.877551  1.508761  101.0  102.00  103.0
# 20915                  50.0  103.020000  1.531839  101.0  102.00  103.0
# 20919                  43.0  102.511628  1.279362  101.0  101.50  102.0
# 20970                  44.0  102.318182  1.289902  101.0  101.00  102.0
# 21169                  50.0  103.160000  1.620783  101.0  102.00  103.0
# 21237                  46.0  102.695652  1.488766  101.0  101.25  102.0
# 21317                  48.0  103.083333  1.268830  101.0  102.00  103.0
# 21328                  46.0  102.891304  1.622457  101.0  101.25  102.5
# 21340                  48.0  102.979167  1.577631  101.0  101.75  103.0
# 21420                  40.0  102.900000  1.565657  101.0  101.75  103.0
# 21444                  40.0  103.450000  1.218448  101.0  103.00  104.0
# 21497                  48.0  102.916667  1.527525  101.0  102.00  103.0
# 21500                  44.0  102.977273  1.562476  101.0  102.00  102.0
# 21529                  43.0  102.488372  0.960459  101.0  102.00  102.0
# 21543                  42.0  102.404762  0.964227  101.0  102.00  102.0
# 21553                  49.0  102.530612  1.355576  101.0  102.00  102.0
# 21600                  49.0  102.489796  1.355889  101.0  101.00  102.0
# 21616                  41.0  102.390244  1.357904  101.0  101.00  102.0
# 21627                  40.0  102.575000  1.356608  101.0  102.00  102.0
# 21660                  43.0  103.069767  1.502305  101.0  102.00  103.0
# 21666                  47.0  103.446809  1.742169  101.0  102.00  105.0
# 21696                  46.0  102.978261  1.512748  101.0  102.00  103.0
# 21724                  42.0  102.738095  1.380341  101.0  102.00  102.5
# 21733                  44.0  102.613636  1.417760  101.0  101.75  102.0
# 21772                  43.0  103.186047  1.500092  101.0  102.00  103.0
# 21783                  42.0  102.690476  1.405357  101.0  102.00  102.0
# 21793                  50.0  102.080000  0.853325  101.0  101.25  102.0
# 21803                  46.0  102.500000  1.169045  101.0  102.00  102.5
# 21805                  49.0  102.714286  1.443376  101.0  102.00  103.0
# 21865                  48.0  103.625000  1.408560  101.0  102.75  104.0
# 21877                  41.0  103.195122  1.600305  101.0  102.00  103.0
# 21945                  41.0  102.365854  1.299155  101.0  101.00  102.0
# 22024                  45.0  103.133333  1.603972  101.0  102.00  103.0
# 22065                  40.0  102.550000  1.616422  101.0  101.00  102.0
# 22067                  41.0  102.365854  1.219756  101.0  101.00  102.0
#
#                          first_cate_code              ... 597695.5      \
#               75%    max           count        mean  ...      75% max
# item_code                                             ...
# 20098      103.00  105.0            49.0  304.918367  ...      NaN NaN
# 20105      103.00  105.0            49.0  304.326531  ...      NaN NaN
# 20218      105.00  105.0            50.0  305.180000  ...      NaN NaN
# 20429      105.00  105.0            43.0  304.279070  ...      NaN NaN
# 20520      103.00  105.0            45.0  304.644444  ...      NaN NaN
# 20572      105.00  105.0            44.0  305.159091  ...      NaN NaN
# 20594      103.00  105.0            42.0  304.666667  ...      NaN NaN
# 20603      103.00  105.0            45.0  304.777778  ...      NaN NaN
# 20607      105.00  105.0            50.0  304.820000  ...      NaN NaN
# 20639      105.00  105.0            43.0  304.046512  ...      NaN NaN
# 20680      103.00  105.0            46.0  304.304348  ...      NaN NaN
# 20711      104.00  105.0            49.0  304.428571  ...      NaN NaN
# 20915      105.00  105.0            50.0  304.520000  ...      NaN NaN
# 20919      103.00  105.0            43.0  304.395349  ...      NaN NaN
# 20970      103.00  105.0            44.0  305.477273  ...      NaN NaN
# 21169      105.00  105.0            50.0  304.940000  ...      NaN NaN
# 21237      103.00  105.0            46.0  305.304348  ...      NaN NaN
# 21317      104.00  105.0            48.0  304.770833  ...      NaN NaN
# 21328      105.00  105.0            46.0  305.260870  ...      NaN NaN
# 21340      105.00  105.0            48.0  304.833333  ...      NaN NaN
# 21420      105.00  105.0            40.0  305.700000  ...      NaN NaN
# 21444      104.00  105.0            40.0  304.600000  ...      NaN NaN
# 21497      105.00  105.0            48.0  305.500000  ...      NaN NaN
# 21500      105.00  105.0            44.0  305.886364  ...      NaN NaN
# 21529      103.00  105.0            43.0  304.837209  ...      NaN NaN
# 21543      103.00  105.0            42.0  305.428571  ...      NaN NaN
# 21553      103.00  105.0            49.0  305.306122  ...      NaN NaN
# 21600      103.00  105.0            49.0  305.306122  ...      NaN NaN
# 21616      103.00  105.0            41.0  305.536585  ...      NaN NaN
# 21627      103.00  105.0            40.0  304.700000  ...      NaN NaN
# 21660      105.00  105.0            43.0  305.069767  ...      NaN NaN
# 21666      105.00  105.0            47.0  305.553191  ...      NaN NaN
# 21696      105.00  105.0            46.0  305.434783  ...      NaN NaN
# 21724      104.00  105.0            42.0  304.904762  ...      NaN NaN
# 21733      103.00  105.0            44.0  305.636364  ...      NaN NaN
# 21772      105.00  105.0            43.0  305.627907  ...      NaN NaN
# 21783      103.75  105.0            42.0  305.095238  ...      NaN NaN
# 21793      103.00  105.0            50.0  305.300000  ...      NaN NaN
# 21803      103.00  105.0            46.0  305.934783  ...      NaN NaN
# 21805      103.00  105.0            49.0  305.530612  ...      NaN NaN
# 21865      105.00  105.0            48.0  305.395833  ...      NaN NaN
# 21877      105.00  105.0            41.0  305.536585  ...      NaN NaN
# 21945      103.00  105.0            41.0  305.780488  ...      NaN NaN
# 22024      105.00  105.0            45.0  306.044444  ...      NaN NaN
# 22065      103.50  105.0            40.0  305.425000  ...      NaN NaN
# 22067      103.00  105.0            41.0  305.439024  ...      NaN NaN
#
#           597695.6
#              count mean std min 25% 50% 75% max
# item_code
# 20098          0.0  NaN NaN NaN NaN NaN NaN NaN
# 20105          0.0  NaN NaN NaN NaN NaN NaN NaN
# 20218          0.0  NaN NaN NaN NaN NaN NaN NaN
# 20429          0.0  NaN NaN NaN NaN NaN NaN NaN
# 20520          0.0  NaN NaN NaN NaN NaN NaN NaN
# 20572          0.0  NaN NaN NaN NaN NaN NaN NaN
# 20594          0.0  NaN NaN NaN NaN NaN NaN NaN
# 20603          0.0  NaN NaN NaN NaN NaN NaN NaN
# 20607          0.0  NaN NaN NaN NaN NaN NaN NaN
# 20639          0.0  NaN NaN NaN NaN NaN NaN NaN
# 20680          0.0  NaN NaN NaN NaN NaN NaN NaN
# 20711          0.0  NaN NaN NaN NaN NaN NaN NaN
# 20915          0.0  NaN NaN NaN NaN NaN NaN NaN
# 20919          0.0  NaN NaN NaN NaN NaN NaN NaN
# 20970          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21169          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21237          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21317          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21328          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21340          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21420          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21444          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21497          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21500          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21529          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21543          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21553          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21600          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21616          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21627          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21660          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21666          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21696          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21724          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21733          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21772          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21783          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21793          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21803          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21805          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21865          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21877          0.0  NaN NaN NaN NaN NaN NaN NaN
# 21945          0.0  NaN NaN NaN NaN NaN NaN NaN
# 22024          0.0  NaN NaN NaN NaN NaN NaN NaN
# 22065          0.0  NaN NaN NaN NaN NaN NaN NaN
# 22067          0.0  NaN NaN NaN NaN NaN NaN NaN
#
# [46 rows x 96 columns]

# %%
type(group)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
group.get_group(21875)
# Out:
#        order_date  sales_region_code  item_code  first_cate_code  \
# 56952  2017/10/20                103      21875              306
# 56953  2017/10/24                105      21875              301
# 56954  2017/10/31                105      21875              302
# 56955   2017/11/2                105      21875              301
# 56956   2017/11/7                103      21875              307
# 56957  2017/11/11                105      21875              306
# 56958  2017/11/16                102      21875              308
# 56959  2017/11/20                102      21875              307
# 56960  2017/11/24                102      21875              308
# 56961  2017/11/28                105      21875              304
# 56962  2017/11/29                101      21875              308
# 56963   2017/12/8                101      21875              307
#
#        second_cate_code sales_chan_name  item_price  ord_qty  597695  \
# 56952               407         offline       816.0      225     NaN
# 56953               405          online       813.0      225     NaN
# 56954               408          online       802.0      225     NaN
# 56955               405          online       799.0      225     NaN
# 56956               403         offline       793.0      225     NaN
# 56957               407          online       787.0      225     NaN
# 56958               404         offline       781.0      225     NaN
# 56959               403         offline       777.0      225     NaN
# 56960               404         offline       773.0      225     NaN
# 56961               409         offline       770.0      225     NaN
# 56962               404         offline       768.0      225     NaN
# 56963               403         offline       762.0      225     NaN
#
#        597695.1  597695.2  597695.3  597695.4  597695.5  597695.6
# 56952       NaN       NaN       NaN       NaN       NaN       NaN
# 56953       NaN       NaN       NaN       NaN       NaN       NaN
# 56954       NaN       NaN       NaN       NaN       NaN       NaN
# 56955       NaN       NaN       NaN       NaN       NaN       NaN
# 56956       NaN       NaN       NaN       NaN       NaN       NaN
# 56957       NaN       NaN       NaN       NaN       NaN       NaN
# 56958       NaN       NaN       NaN       NaN       NaN       NaN
# 56959       NaN       NaN       NaN       NaN       NaN       NaN
# 56960       NaN       NaN       NaN       NaN       NaN       NaN
# 56961       NaN       NaN       NaN       NaN       NaN       NaN
# 56962       NaN       NaN       NaN       NaN       NaN       NaN
# 56963       NaN       NaN       NaN       NaN       NaN       NaN

# %%
size=group.size()

# %%
type(size)
# Out:
# pandas.core.series.Series

# %%
plt.figure(dpi=300,figsize=(10,10))
size.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='item_code'>

# %%
group21875=group.get_group(21875)

# %%
group21875
# Out:
#        order_date  sales_region_code  item_code  first_cate_code  \
# 56952  2017/10/20                103      21875              306
# 56953  2017/10/24                105      21875              301
# 56954  2017/10/31                105      21875              302
# 56955   2017/11/2                105      21875              301
# 56956   2017/11/7                103      21875              307
# 56957  2017/11/11                105      21875              306
# 56958  2017/11/16                102      21875              308
# 56959  2017/11/20                102      21875              307
# 56960  2017/11/24                102      21875              308
# 56961  2017/11/28                105      21875              304
# 56962  2017/11/29                101      21875              308
# 56963   2017/12/8                101      21875              307
#
#        second_cate_code sales_chan_name  item_price  ord_qty  597695  \
# 56952               407         offline       816.0      225     NaN
# 56953               405          online       813.0      225     NaN
# 56954               408          online       802.0      225     NaN
# 56955               405          online       799.0      225     NaN
# 56956               403         offline       793.0      225     NaN
# 56957               407          online       787.0      225     NaN
# 56958               404         offline       781.0      225     NaN
# 56959               403         offline       777.0      225     NaN
# 56960               404         offline       773.0      225     NaN
# 56961               409         offline       770.0      225     NaN
# 56962               404         offline       768.0      225     NaN
# 56963               403         offline       762.0      225     NaN
#
#        597695.1  597695.2  597695.3  597695.4  597695.5  597695.6
# 56952       NaN       NaN       NaN       NaN       NaN       NaN
# 56953       NaN       NaN       NaN       NaN       NaN       NaN
# 56954       NaN       NaN       NaN       NaN       NaN       NaN
# 56955       NaN       NaN       NaN       NaN       NaN       NaN
# 56956       NaN       NaN       NaN       NaN       NaN       NaN
# 56957       NaN       NaN       NaN       NaN       NaN       NaN
# 56958       NaN       NaN       NaN       NaN       NaN       NaN
# 56959       NaN       NaN       NaN       NaN       NaN       NaN
# 56960       NaN       NaN       NaN       NaN       NaN       NaN
# 56961       NaN       NaN       NaN       NaN       NaN       NaN
# 56962       NaN       NaN       NaN       NaN       NaN       NaN
# 56963       NaN       NaN       NaN       NaN       NaN       NaN

# %%
sns.boxplot(data=group21875["item_price"].values)
# Out:
# <AxesSubplot:>

# %%
group21875["item_price"]
# Out:
# 56952    816.0
# 56953    813.0
# 56954    802.0
# 56955    799.0
# 56956    793.0
# 56957    787.0
# 56958    781.0
# 56959    777.0
# 56960    773.0
# 56961    770.0
# 56962    768.0
# 56963    762.0
# Name: item_price, dtype: float64

# %%
group20003=group.get_group(20003)

# %%
group20003
# Out:
#         order_date  sales_region_code  item_code  first_cate_code  \
# 594220    2018/9/4                101      20003              305
# 594221    2018/9/4                103      20003              303
# 594222    2018/9/4                103      20003              302
# 594223    2018/9/4                103      20003              302
# 594224    2018/9/4                101      20003              302
# ...            ...                ...        ...              ...
# 596982   2017/12/1                105      20003              303
# 596983   2017/12/1                105      20003              303
# 596984   2017/12/8                105      20003              308
# 596985   2017/12/8                105      20003              307
# 596986  2017/12/11                105      20003              303
#
#         second_cate_code sales_chan_name  item_price  ord_qty  597695  \
# 594220               412         offline       484.0        2     NaN
# 594221               406         offline       484.0        2     NaN
# 594222               408         offline       484.0        2     NaN
# 594223               408         offline       484.0        2     NaN
# 594224               408         offline       484.0        2     NaN
# ...                  ...             ...         ...      ...     ...
# 596982               406         offline       767.0        1     NaN
# 596983               406         offline       767.0        1     NaN
# 596984               404         offline       762.0        1     NaN
# 596985               403         offline       762.0        1     NaN
# 596986               406         offline       760.0        1     NaN
#
#         597695.1  597695.2  597695.3  597695.4  597695.5  597695.6
# 594220       NaN       NaN       NaN       NaN       NaN       NaN
# 594221       NaN       NaN       NaN       NaN       NaN       NaN
# 594222       NaN       NaN       NaN       NaN       NaN       NaN
# 594223       NaN       NaN       NaN       NaN       NaN       NaN
# 594224       NaN       NaN       NaN       NaN       NaN       NaN
# ...          ...       ...       ...       ...       ...       ...
# 596982       NaN       NaN       NaN       NaN       NaN       NaN
# 596983       NaN       NaN       NaN       NaN       NaN       NaN
# 596984       NaN       NaN       NaN       NaN       NaN       NaN
# 596985       NaN       NaN       NaN       NaN       NaN       NaN
# 596986       NaN       NaN       NaN       NaN       NaN       NaN
#
# [2767 rows x 15 columns]

# %%
plt.figure(dpi=100,figsize=(4,4))
sns.boxplot(data=group20003["item_price"].values)
# Out:
# <AxesSubplot:>

# %%
ymean=np.mean(group20003["item_price"].values)

# %%
ystd=np.std(group20003["item_price"].values)

# %%
threshold1=ymean-3*ystd
threshold2=ymean+3*ystd

# %%
dropIndex=[]
for i in range(len(group20003["item_price"].values)):
    if(group20003["item_price"].values[i]<threshold1 or group20003["item_price"].values[i]>threshold2):
        dropIndex.append(i)

# %%
group20003.index=range(len(group20003))

# %%
dropIndex
for i in dropIndex:
    group20003=group20003.drop(index=i)

# %%
group20003
# Out:
#       order_date  sales_region_code  item_code  first_cate_code  \
# 0       2018/9/4                101      20003              305
# 1       2018/9/4                103      20003              303
# 2       2018/9/4                103      20003              302
# 3       2018/9/4                103      20003              302
# 4       2018/9/4                101      20003              302
# ...          ...                ...        ...              ...
# 2762   2017/12/1                105      20003              303
# 2763   2017/12/1                105      20003              303
# 2764   2017/12/8                105      20003              308
# 2765   2017/12/8                105      20003              307
# 2766  2017/12/11                105      20003              303
#
#       second_cate_code sales_chan_name  item_price  ord_qty  597695  597695.1  \
# 0                  412         offline       484.0        2     NaN       NaN
# 1                  406         offline       484.0        2     NaN       NaN
# 2                  408         offline       484.0        2     NaN       NaN
# 3                  408         offline       484.0        2     NaN       NaN
# 4                  408         offline       484.0        2     NaN       NaN
# ...                ...             ...         ...      ...     ...       ...
# 2762               406         offline       767.0        1     NaN       NaN
# 2763               406         offline       767.0        1     NaN       NaN
# 2764               404         offline       762.0        1     NaN       NaN
# 2765               403         offline       762.0        1     NaN       NaN
# 2766               406         offline       760.0        1     NaN       NaN
#
#       597695.2  597695.3  597695.4  597695.5  597695.6
# 0          NaN       NaN       NaN       NaN       NaN
# 1          NaN       NaN       NaN       NaN       NaN
# 2          NaN       NaN       NaN       NaN       NaN
# 3          NaN       NaN       NaN       NaN       NaN
# 4          NaN       NaN       NaN       NaN       NaN
# ...        ...       ...       ...       ...       ...
# 2762       NaN       NaN       NaN       NaN       NaN
# 2763       NaN       NaN       NaN       NaN       NaN
# 2764       NaN       NaN       NaN       NaN       NaN
# 2765       NaN       NaN       NaN       NaN       NaN
# 2766       NaN       NaN       NaN       NaN       NaN
#
# [2733 rows x 15 columns]

# %%
plt.figure(dpi=100,figsize=(4,4))
sns.boxplot(data=group20003["item_price"].values)
# Out:
# <AxesSubplot:>

# %%
item_code=data_train["item_code"].unique()

# %%
item_code
# Out:
# array([22084, 22083, 22082, ..., 20003, 20002, 20001], dtype=int64)

# %%
# 筛除异常值
groups=[]
for i in item_code:
    group1=group.get_group(i)
    ymean=np.mean(group1["item_price"].values)
    ystd=np.std(group1["item_price"].values)
    threshold1=ymean-3*ystd
    threshold2=ymean+3*ystd
    dropIndex=[]
    for i in range(len(group1["item_price"].values)):
        if(group1["item_price"].values[i]<threshold1 or group1["item_price"].values[i]>threshold2):
            dropIndex.append(i)
    group1.index=range(len(group1))
    for i in dropIndex:
        group1=group1.drop(index=i)
    groups.append(group1)

# %%
len(groups)
# Out:
# 1758

# %%
data_new=pd.concat(groups)

# %%
data_new
# Out:
#     order_date  sales_region_code  item_code  first_cate_code  \
# 0   2015/11/12                105      22084              306
# 1   2015/11/12                101      22084              306
# 2   2017/10/21                101      22084              306
# 3   2017/10/23                101      22084              306
# 4   2015/10/24                101      22084              305
# ..         ...                ...        ...              ...
# 8   2018/12/20                102      20001              306
# 9   2018/12/20                102      20001              306
# 10  2018/12/20                102      20001              306
# 11  2018/12/20                102      20001              302
# 12  2018/12/20                102      20001              302
#
#     second_cate_code sales_chan_name  item_price  ord_qty  597695  597695.1  \
# 0                402          online     2764.00    16308     NaN       NaN
# 1                402         offline     2762.00    16301     NaN       NaN
# 2                407         offline      815.00    12481     NaN       NaN
# 3                407         offline      813.00    12480     NaN       NaN
# 4                412         offline     3005.00    10825     NaN       NaN
# ..               ...             ...         ...      ...     ...       ...
# 8                407         offline        7.01        1     NaN       NaN
# 9                407         offline        7.01        1     NaN       NaN
# 10               407         offline        7.01        1     NaN       NaN
# 11               408         offline        7.01        1     NaN       NaN
# 12               408         offline        6.01        1     NaN       NaN
#
#     597695.2  597695.3  597695.4  597695.5  597695.6
# 0        NaN       NaN       NaN       NaN       NaN
# 1        NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN       NaN       NaN       NaN
# 3        NaN       NaN       NaN       NaN       NaN
# 4        NaN       NaN       NaN       NaN       NaN
# ..       ...       ...       ...       ...       ...
# 8        NaN       NaN       NaN       NaN       NaN
# 9        NaN       NaN       NaN       NaN       NaN
# 10       NaN       NaN       NaN       NaN       NaN
# 11       NaN       NaN       NaN       NaN       NaN
# 12       NaN       NaN       NaN       NaN       NaN
#
# [594808 rows x 15 columns]

# %%
data_new.index=range(len(data_new))

# %%
data_new
# Out:
#         order_date  sales_region_code  item_code  first_cate_code  \
# 0       2015/11/12                105      22084              306
# 1       2015/11/12                101      22084              306
# 2       2017/10/21                101      22084              306
# 3       2017/10/23                101      22084              306
# 4       2015/10/24                101      22084              305
# ...            ...                ...        ...              ...
# 594803  2018/12/20                102      20001              306
# 594804  2018/12/20                102      20001              306
# 594805  2018/12/20                102      20001              306
# 594806  2018/12/20                102      20001              302
# 594807  2018/12/20                102      20001              302
#
#         second_cate_code sales_chan_name  item_price  ord_qty  597695  \
# 0                    402          online     2764.00    16308     NaN
# 1                    402         offline     2762.00    16301     NaN
# 2                    407         offline      815.00    12481     NaN
# 3                    407         offline      813.00    12480     NaN
# 4                    412         offline     3005.00    10825     NaN
# ...                  ...             ...         ...      ...     ...
# 594803               407         offline        7.01        1     NaN
# 594804               407         offline        7.01        1     NaN
# 594805               407         offline        7.01        1     NaN
# 594806               408         offline        7.01        1     NaN
# 594807               408         offline        6.01        1     NaN
#
#         597695.1  597695.2  597695.3  597695.4  597695.5  597695.6
# 0            NaN       NaN       NaN       NaN       NaN       NaN
# 1            NaN       NaN       NaN       NaN       NaN       NaN
# 2            NaN       NaN       NaN       NaN       NaN       NaN
# 3            NaN       NaN       NaN       NaN       NaN       NaN
# 4            NaN       NaN       NaN       NaN       NaN       NaN
# ...          ...       ...       ...       ...       ...       ...
# 594803       NaN       NaN       NaN       NaN       NaN       NaN
# 594804       NaN       NaN       NaN       NaN       NaN       NaN
# 594805       NaN       NaN       NaN       NaN       NaN       NaN
# 594806       NaN       NaN       NaN       NaN       NaN       NaN
# 594807       NaN       NaN       NaN       NaN       NaN       NaN
#
# [594808 rows x 15 columns]

# %%
group_new=data_new.groupby("item_code")

# %%
group_new.describe()
# Out:
#           sales_region_code                                                    \
#                       count        mean       std    min    25%    50%    75%
# item_code
# 20001                  13.0  102.076923  0.640513  101.0  102.0  102.0  102.0
# 20002                 694.0  102.377522  1.172736  101.0  102.0  102.0  103.0
# 20003                2733.0  102.650201  1.368650  101.0  101.0  103.0  103.0
# 20005                  20.0  102.650000  1.182103  101.0  102.0  102.0  103.0
# 20006                1523.0  102.606041  1.408540  101.0  101.0  102.0  103.0
# ...                     ...         ...       ...    ...    ...    ...    ...
# 22080                1700.0  103.222353  1.549640  101.0  102.0  103.0  105.0
# 22081                1252.0  103.127796  1.583678  101.0  102.0  103.0  105.0
# 22082                 157.0  103.044586  1.618578  101.0  101.0  103.0  105.0
# 22083                 308.0  102.935065  1.654823  101.0  101.0  103.0  105.0
# 22084                 465.0  102.832258  1.644555  101.0  101.0  103.0  105.0
#
#                  first_cate_code              ... 597695.5     597695.6       \
#              max           count        mean  ...      75% max    count mean
# item_code                                     ...
# 20001      103.0            13.0  303.846154  ...      NaN NaN      0.0  NaN
# 20002      105.0           694.0  304.203170  ...      NaN NaN      0.0  NaN
# 20003      105.0          2733.0  304.666301  ...      NaN NaN      0.0  NaN
# 20005      105.0            20.0  305.050000  ...      NaN NaN      0.0  NaN
# 20006      105.0          1523.0  304.546947  ...      NaN NaN      0.0  NaN
# ...          ...             ...         ...  ...      ...  ..      ...  ...
# 22080      105.0          1700.0  305.695882  ...      NaN NaN      0.0  NaN
# 22081      105.0          1252.0  305.633387  ...      NaN NaN      0.0  NaN
# 22082      105.0           157.0  305.585987  ...      NaN NaN      0.0  NaN
# 22083      105.0           308.0  305.509740  ...      NaN NaN      0.0  NaN
# 22084      105.0           465.0  305.610753  ...      NaN NaN      0.0  NaN
#
#
#           std min 25% 50% 75% max
# item_code
# 20001     NaN NaN NaN NaN NaN NaN
# 20002     NaN NaN NaN NaN NaN NaN
# 20003     NaN NaN NaN NaN NaN NaN
# 20005     NaN NaN NaN NaN NaN NaN
# 20006     NaN NaN NaN NaN NaN NaN
# ...        ..  ..  ..  ..  ..  ..
# 22080     NaN NaN NaN NaN NaN NaN
# 22081     NaN NaN NaN NaN NaN NaN
# 22082     NaN NaN NaN NaN NaN NaN
# 22083     NaN NaN NaN NaN NaN NaN
# 22084     NaN NaN NaN NaN NaN NaN
#
# [1758 rows x 96 columns]

# %%
data_new.to_csv("C:/Users/Lenovo/Desktop/Teddy_Git/order_train_new.csv")

# %%
group20003
# Out:
#       order_date  sales_region_code  item_code  first_cate_code  \
# 0       2018/9/4                101      20003              305
# 1       2018/9/4                103      20003              303
# 2       2018/9/4                103      20003              302
# 3       2018/9/4                103      20003              302
# 4       2018/9/4                101      20003              302
# ...          ...                ...        ...              ...
# 2762   2017/12/1                105      20003              303
# 2763   2017/12/1                105      20003              303
# 2764   2017/12/8                105      20003              308
# 2765   2017/12/8                105      20003              307
# 2766  2017/12/11                105      20003              303
#
#       second_cate_code sales_chan_name  item_price  ord_qty  597695  597695.1  \
# 0                  412         offline       484.0        2     NaN       NaN
# 1                  406         offline       484.0        2     NaN       NaN
# 2                  408         offline       484.0        2     NaN       NaN
# 3                  408         offline       484.0        2     NaN       NaN
# 4                  408         offline       484.0        2     NaN       NaN
# ...                ...             ...         ...      ...     ...       ...
# 2762               406         offline       767.0        1     NaN       NaN
# 2763               406         offline       767.0        1     NaN       NaN
# 2764               404         offline       762.0        1     NaN       NaN
# 2765               403         offline       762.0        1     NaN       NaN
# 2766               406         offline       760.0        1     NaN       NaN
#
#       597695.2  597695.3  597695.4  597695.5  597695.6
# 0          NaN       NaN       NaN       NaN       NaN
# 1          NaN       NaN       NaN       NaN       NaN
# 2          NaN       NaN       NaN       NaN       NaN
# 3          NaN       NaN       NaN       NaN       NaN
# 4          NaN       NaN       NaN       NaN       NaN
# ...        ...       ...       ...       ...       ...
# 2762       NaN       NaN       NaN       NaN       NaN
# 2763       NaN       NaN       NaN       NaN       NaN
# 2764       NaN       NaN       NaN       NaN       NaN
# 2765       NaN       NaN       NaN       NaN       NaN
# 2766       NaN       NaN       NaN       NaN       NaN
#
# [2733 rows x 15 columns]

# %%
x=group21875["order_date"]

# %%
x
# Out:
# 56952    2017/10/20
# 56953    2017/10/24
# 56954    2017/10/31
# 56955     2017/11/2
# 56956     2017/11/7
# 56957    2017/11/11
# 56958    2017/11/16
# 56959    2017/11/20
# 56960    2017/11/24
# 56961    2017/11/28
# 56962    2017/11/29
# 56963     2017/12/8
# Name: order_date, dtype: object

# %%
y=group21875["ord_qty"]

# %%
y
# Out:
# 56952    225
# 56953    225
# 56954    225
# 56955    225
# 56956    225
# 56957    225
# 56958    225
# 56959    225
# 56960    225
# 56961    225
# 56962    225
# 56963    225
# Name: ord_qty, dtype: int64

# %%
plt.figure(dpi=250,figsize=(20,5))
plt.xticks(rotation=45)
plt.plot(x,y,'s-',color = 'r')

# %%
group21875
# Out:
#        order_date  sales_region_code  item_code  first_cate_code  \
# 56952  2017/10/20                103      21875              306
# 56953  2017/10/24                105      21875              301
# 56954  2017/10/31                105      21875              302
# 56955   2017/11/2                105      21875              301
# 56956   2017/11/7                103      21875              307
# 56957  2017/11/11                105      21875              306
# 56958  2017/11/16                102      21875              308
# 56959  2017/11/20                102      21875              307
# 56960  2017/11/24                102      21875              308
# 56961  2017/11/28                105      21875              304
# 56962  2017/11/29                101      21875              308
# 56963   2017/12/8                101      21875              307
#
#        second_cate_code sales_chan_name  item_price  ord_qty  597695  \
# 56952               407         offline       816.0      225     NaN
# 56953               405          online       813.0      225     NaN
# 56954               408          online       802.0      225     NaN
# 56955               405          online       799.0      225     NaN
# 56956               403         offline       793.0      225     NaN
# 56957               407          online       787.0      225     NaN
# 56958               404         offline       781.0      225     NaN
# 56959               403         offline       777.0      225     NaN
# 56960               404         offline       773.0      225     NaN
# 56961               409         offline       770.0      225     NaN
# 56962               404         offline       768.0      225     NaN
# 56963               403         offline       762.0      225     NaN
#
#        597695.1  597695.2  597695.3  597695.4  597695.5  597695.6
# 56952       NaN       NaN       NaN       NaN       NaN       NaN
# 56953       NaN       NaN       NaN       NaN       NaN       NaN
# 56954       NaN       NaN       NaN       NaN       NaN       NaN
# 56955       NaN       NaN       NaN       NaN       NaN       NaN
# 56956       NaN       NaN       NaN       NaN       NaN       NaN
# 56957       NaN       NaN       NaN       NaN       NaN       NaN
# 56958       NaN       NaN       NaN       NaN       NaN       NaN
# 56959       NaN       NaN       NaN       NaN       NaN       NaN
# 56960       NaN       NaN       NaN       NaN       NaN       NaN
# 56961       NaN       NaN       NaN       NaN       NaN       NaN
# 56962       NaN       NaN       NaN       NaN       NaN       NaN
# 56963       NaN       NaN       NaN       NaN       NaN       NaN

# %%
group.get_group(21169)
# Out:
#        order_date  sales_region_code  item_code  first_cate_code  \
# 238412  2017/5/24                105      21169              306
# 238413  2017/5/24                105      21169              307
# 238414  2017/5/24                102      21169              303
# 238415  2017/5/25                102      21169              302
# 238416  2017/5/25                101      21169              307
# 238417  2017/5/25                105      21169              306
# 238418  2017/5/25                105      21169              306
# 238419  2017/5/25                103      21169              308
# 238420  2017/5/26                105      21169              306
# 238421  2017/5/26                101      21169              305
# 238422  2017/5/27                105      21169              306
# 238423  2017/5/27                102      21169              303
# 238424  2017/5/27                105      21169              306
# 238425  2017/5/27                105      21169              306
# 238426  2017/5/27                103      21169              302
# 238427  2017/5/27                102      21169              303
# 238428  2017/5/27                101      21169              302
# 238429  2017/5/28                102      21169              306
# 238430  2017/5/28                103      21169              308
# 238431  2017/5/28                102      21169              303
# 238432  2017/5/29                101      21169              306
# 238433  2017/5/30                105      21169              304
# 238434   2017/6/1                102      21169              306
# 238435   2017/6/3                105      21169              306
# 238436   2017/6/3                101      21169              305
# 238437   2017/6/4                105      21169              306
# 238438   2017/6/6                102      21169              305
# 238439   2017/6/6                105      21169              301
# 238440   2017/6/6                103      21169              305
# 238441   2017/6/6                101      21169              308
# 238442   2017/6/6                101      21169              305
# 238443   2017/6/7                105      21169              304
# 238444   2017/6/8                105      21169              307
# 238445   2017/6/8                105      21169              302
# 238446   2017/6/8                105      21169              302
# 238447   2017/6/9                102      21169              306
# 238448   2017/6/9                102      21169              303
# 238449  2017/6/10                103      21169              303
# 238450  2017/6/10                105      21169              308
# 238451  2017/6/11                105      21169              306
# 238452  2017/6/11                105      21169              304
# 238453  2017/6/11                101      21169              302
# 238454  2017/6/11                103      21169              308
# 238455  2017/6/12                105      21169              307
# 238456  2017/6/12                101      21169              302
# 238457  2017/6/12                102      21169              308
# 238458  2017/6/13                103      21169              306
# 238459  2017/6/13                102      21169              302
# 238460  2017/6/13                102      21169              303
# 238461  2017/6/13                102      21169              306
#
#         second_cate_code sales_chan_name  item_price  ord_qty  597695  \
# 238412               407          online       977.0       47     NaN
# 238413               403          online       977.0       47     NaN
# 238414               401         offline       976.0       47     NaN
# 238415               408         offline       975.0       47     NaN
# 238416               403         offline       974.0       47     NaN
# 238417               407          online       973.0       47     NaN
# 238418               402          online       973.0       47     NaN
# 238419               404         offline       972.0       47     NaN
# 238420               407          online       971.0       47     NaN
# 238421               412         offline       971.0       47     NaN
# 238422               407          online       969.0       47     NaN
# 238423               401         offline       969.0       47     NaN
# 238424               402          online       968.0       47     NaN
# 238425               407          online       968.0       47     NaN
# 238426               408         offline       968.0       47     NaN
# 238427               401         offline       968.0       47     NaN
# 238428               408         offline       968.0       47     NaN
# 238429               407         offline       967.0       47     NaN
# 238430               404         offline       966.0       47     NaN
# 238431               401         offline       966.0       47     NaN
# 238432               407         offline       965.0       47     NaN
# 238433               409         offline       965.0       47     NaN
# 238434               402         offline       963.0       47     NaN
# 238435               407          online       963.0       47     NaN
# 238436               412         offline       963.0       47     NaN
# 238437               407          online       962.0       47     NaN
# 238438               412         offline       961.0       47     NaN
# 238439               405          online       961.0       47     NaN
# 238440               412         offline       961.0       47     NaN
# 238441               404         offline       960.0       47     NaN
# 238442               412         offline       960.0       47     NaN
# 238443               409         offline       960.0       47     NaN
# 238444               403          online       959.0       47     NaN
# 238445               408         offline       959.0       47     NaN
# 238446               408         offline       959.0       47     NaN
# 238447               407         offline       957.0       47     NaN
# 238448               401         offline       957.0       47     NaN
# 238449               401         offline       957.0       47     NaN
# 238450               404          online       956.0       47     NaN
# 238451               407          online       956.0       47     NaN
# 238452               409         offline       955.0       47     NaN
# 238453               408         offline       955.0       47     NaN
# 238454               404         offline       955.0       47     NaN
# 238455               403          online       954.0       47     NaN
# 238456               408         offline       954.0       47     NaN
# 238457               404         offline       954.0       47     NaN
# 238458               407         offline       954.0       47     NaN
# 238459               408         offline       954.0       47     NaN
# 238460               401         offline       954.0       47     NaN
# 238461               407         offline       953.0       47     NaN
#
#         597695.1  597695.2  597695.3  597695.4  597695.5  597695.6
# 238412       NaN       NaN       NaN       NaN       NaN       NaN
# 238413       NaN       NaN       NaN       NaN       NaN       NaN
# 238414       NaN       NaN       NaN       NaN       NaN       NaN
# 238415       NaN       NaN       NaN       NaN       NaN       NaN
# 238416       NaN       NaN       NaN       NaN       NaN       NaN
# 238417       NaN       NaN       NaN       NaN       NaN       NaN
# 238418       NaN       NaN       NaN       NaN       NaN       NaN
# 238419       NaN       NaN       NaN       NaN       NaN       NaN
# 238420       NaN       NaN       NaN       NaN       NaN       NaN
# 238421       NaN       NaN       NaN       NaN       NaN       NaN
# 238422       NaN       NaN       NaN       NaN       NaN       NaN
# 238423       NaN       NaN       NaN       NaN       NaN       NaN
# 238424       NaN       NaN       NaN       NaN       NaN       NaN
# 238425       NaN       NaN       NaN       NaN       NaN       NaN
# 238426       NaN       NaN       NaN       NaN       NaN       NaN
# 238427       NaN       NaN       NaN       NaN       NaN       NaN
# 238428       NaN       NaN       NaN       NaN       NaN       NaN
# 238429       NaN       NaN       NaN       NaN       NaN       NaN
# 238430       NaN       NaN       NaN       NaN       NaN       NaN
# 238431       NaN       NaN       NaN       NaN       NaN       NaN
# 238432       NaN       NaN       NaN       NaN       NaN       NaN
# 238433       NaN       NaN       NaN       NaN       NaN       NaN
# 238434       NaN       NaN       NaN       NaN       NaN       NaN
# 238435       NaN       NaN       NaN       NaN       NaN       NaN
# 238436       NaN       NaN       NaN       NaN       NaN       NaN
# 238437       NaN       NaN       NaN       NaN       NaN       NaN
# 238438       NaN       NaN       NaN       NaN       NaN       NaN
# 238439       NaN       NaN       NaN       NaN       NaN       NaN
# 238440       NaN       NaN       NaN       NaN       NaN       NaN
# 238441       NaN       NaN       NaN       NaN       NaN       NaN
# 238442       NaN       NaN       NaN       NaN       NaN       NaN
# 238443       NaN       NaN       NaN       NaN       NaN       NaN
# 238444       NaN       NaN       NaN       NaN       NaN       NaN
# 238445       NaN       NaN       NaN       NaN       NaN       NaN
# 238446       NaN       NaN       NaN       NaN       NaN       NaN
# 238447       NaN       NaN       NaN       NaN       NaN       NaN
# 238448       NaN       NaN       NaN       NaN       NaN       NaN
# 238449       NaN       NaN       NaN       NaN       NaN       NaN
# 238450       NaN       NaN       NaN       NaN       NaN       NaN
# 238451       NaN       NaN       NaN       NaN       NaN       NaN
# 238452       NaN       NaN       NaN       NaN       NaN       NaN
# 238453       NaN       NaN       NaN       NaN       NaN       NaN
# 238454       NaN       NaN       NaN       NaN       NaN       NaN
# 238455       NaN       NaN       NaN       NaN       NaN       NaN
# 238456       NaN       NaN       NaN       NaN       NaN       NaN
# 238457       NaN       NaN       NaN       NaN       NaN       NaN
# 238458       NaN       NaN       NaN       NaN       NaN       NaN
# 238459       NaN       NaN       NaN       NaN       NaN       NaN
# 238460       NaN       NaN       NaN       NaN       NaN       NaN
# 238461       NaN       NaN       NaN       NaN       NaN       NaN

# %%
group21169=group.get_group(21169)

# %%
x=group21169["order_date"]
y=group21169["ord_qty"]

# %%
plt.figure(dpi=250,figsize=(20,5))
plt.xticks(rotation=45)
plt.plot(x,y,'s-',color = 'r')

# %%
group21169_new=group21169[["order_date","ord_qty"]]

# %%
temp=group21169_new.groupby("order_date").sum()

# %%
temp['ord_qty'].values
# Out:
# array([141, 235,  94, 329, 141,  47,  47,  47,  94, 188, 141, 188,  94,
#         47, 235,  47, 141,  94], dtype=int64)

# %%
group21169_new = pd.DataFrame(columns=['order_date', 'ord_qty'])
group21169_new
# Out:
# Empty DataFrame
# Columns: [order_date, ord_qty]
# Index: []

# %%
group21169_new
# Out:
#    order_date  ord_qty
# 0   2017/5/24      141
# 1   2017/5/25      235
# 2   2017/5/26       94
# 3   2017/5/27      329
# 4   2017/5/28      141
# 5   2017/5/29       47
# 6   2017/5/30       47
# 7    2017/6/1       47
# 8   2017/6/10       94
# 9   2017/6/11      188
# 10  2017/6/12      141
# 11  2017/6/13      188
# 12   2017/6/3       94
# 13   2017/6/4       47
# 14   2017/6/6      235
# 15   2017/6/7       47
# 16   2017/6/8      141
# 17   2017/6/9       94

# %%
group21169_new['ord_qty'] = temp['ord_qty'].values
group21169_new['order_date'] = temp['ord_qty'].index
natsorted(group21169_new["order_date"])
# Out:
# ['2017/5/24',
#  '2017/5/25',
#  '2017/5/26',
#  '2017/5/27',
#  '2017/5/28',
#  '2017/5/29',
#  '2017/5/30',
#  '2017/6/1',
#  '2017/6/3',
#  '2017/6/4',
#  '2017/6/6',
#  '2017/6/7',
#  '2017/6/8',
#  '2017/6/9',
#  '2017/6/10',
#  '2017/6/11',
#  '2017/6/12',
#  '2017/6/13']

# %%
# group21169_new_sorted=group21169_new.loc[natsorted(group21169_new["order_date"])].res
#group21169_new.columns
group21169_new_sorted=group21169_new.loc[:,'order_date']
group21169_new_sorted
# Out:
# 0     2017/5/24
# 1     2017/5/25
# 2     2017/5/26
# 3     2017/5/27
# 4     2017/5/28
# 5     2017/5/29
# 6     2017/5/30
# 7      2017/6/1
# 8     2017/6/10
# 9     2017/6/11
# 10    2017/6/12
# 11    2017/6/13
# 12     2017/6/3
# 13     2017/6/4
# 14     2017/6/6
# 15     2017/6/7
# 16     2017/6/8
# 17     2017/6/9
# Name: order_date, dtype: object

# %%
group21169_new_mix["ord_qty"].index

# %%
x=group21169_new["order_date"]
y=group21169_new["ord_qty"]

# %%
plt.figure(dpi=250,figsize=(20,5))
plt.xticks(rotation=45)
plt.plot(x,y,'s-',color = 'r')

# %%
def drawLineChart(i):
    group_draw=group.get_group(i)
    group_draw_new=group_draw[["order_date","ord_qty"]]
    temp=group_draw_new.groupby("order_date").sum()
    group_draw_new1 = pd.DataFrame(columns=['order_date', 'ord_qty'])
    group_draw_new1['ord_qty'] = temp['ord_qty'].values
    group_draw_new1['order_date'] = temp['ord_qty'].index
    x=group_draw_new1["order_date"]
    y=group_draw_new1["ord_qty"]
    plt.figure(dpi=250,figsize=(20,5))
    plt.xticks(rotation=45)
    plt.plot(x,y,'s-',color = 'r')

    plt.tick_params(axis='x', colors='white')
    plt.tick_params(axis='y', colors='white')

# %%
drawLineChart(21169)

# %%
drawLineChart(21317)

# %%
# !pip install natsort

# %%
from natsort import natsorted

# %%
qty_describe = describe["ord_qty"]["count"]

# %%
qty_describe.describe()
# Out:
# count    1758.000000
# mean      339.985210
# std       631.341148
# min         1.000000
# 25%        13.250000
# 50%       110.000000
# 75%       389.000000
# max      8455.000000
# Name: count, dtype: float64

# %%
from scipy.stats import pearsonr
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()

# %%
data_train_new=pd.read_csv("C:/Users/Lenovo/Desktop/Teddy_Git/train_new.csv")

# %%
group_new=data_train_new.groupby("item_code")

# %%
group20457 = group_new.get_group(20457)

# %%
data_train_new

# cols传入连续型变量列名
def plot_con_cat(df, cols=None):
    if cols == None:
        n = np.ceil(len(df.columns))
        data = df.copy()
        cols = df.columns.tolist()
    else:
        n = np.ceil(len(cols))
        data = df.loc[:,cols]
        print(data)



    plt.figure(figsize=(10,8),dpi=100)
    #colors = ['#1E79A6','#349ECE','#54B5E2','#AAE2F8']
    colors = ['#1D2F60','#00416A','#F5F5F5','#FF7F50','#FA8072']
    sales_region_code = ['101','102','103','104','105']
    alphas = [1,0.8,0.6,0.4,0.2]

    ax1 = plt.subplot()
    for i in range(len(data['sales_region_code'].unique())):
        sns.kdeplot(data[data['sales_region_code'] == sales_region_code[i]][cols[8]], color=colors[i], shade=True, ec='black',label=sales_region_code[i],alpha=alphas[i])

    plt.legend()
    ax1.set_ylabel('')
    plt.title('different categories vs continuous variables', fontsize=15)
    plt.legend()
    plt.show()

# %%
plot_con_cat(data_train_new)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4364\1798536950.py:24: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data['sales_region_code'] == sales_region_code[i]][cols[8]], color=colors[i], shade=True, ec='black',label=sales_region_code[i],alpha=alphas[i])
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data_train_new
# Out:
#         Unnamed: 0  order_date  sales_region_code  item_code  first_cate_code  \
# 0                0    2015/9/1                104      22069              307
# 1                1    2015/9/1                104      20028              301
# 2                2    2015/9/2                104      20028              301
# 3                3    2015/9/2                104      21183              307
# 4                4    2015/9/2                104      20448              308
# ...            ...         ...                ...        ...              ...
# 585441      585441  2018/12/20                103      21545              306
# 585442      585442  2018/12/20                103      21545              306
# 585443      585443  2018/12/20                102      21110              307
# 585444      585444  2018/12/20                102      21110              307
# 585445      585445  2018/12/20                105      21320              306
#
#         second_cate_code sales_chan_name  item_price  ord_qty  year  mon  day  \
# 0                    403         offline      1114.0       19  2015    9    1
# 1                    405         offline      1012.0       12  2015    9    1
# 2                    405         offline      1005.0       11  2015    9    2
# 3                    403          online       428.0      109  2015    9    2
# 4                    404          online       962.0        3  2015    9    2
# ...                  ...             ...         ...      ...   ...  ...  ...
# 585441               407         offline      1025.0      105  2018   12   20
# 585442               407         offline      1033.0       99  2018   12   20
# 585443               403         offline      1181.0        5  2018   12   20
# 585444               403         offline      1188.0       11  2018   12   20
# 585445               407         offline       800.0        3  2018   12   20
#
#         offline  online  weekday  is_workday
# 0             1       0        2        True
# 1             1       0        2        True
# 2             1       0        3        True
# 3             0       1        3        True
# 4             0       1        3        True
# ...         ...     ...      ...         ...
# 585441        1       0        4        True
# 585442        1       0        4        True
# 585443        1       0        4        True
# 585444        1       0        4        True
# 585445        1       0        4        True
#
# [585446 rows x 16 columns]

# %%
data_test = data_train_new.loc[:,'ord_qty']
data_test
# Out:
# 0          19
# 1          12
# 2          11
# 3         109
# 4           3
#          ...
# 585441    105
# 585442     99
# 585443      5
# 585444     11
# 585445      3
# Name: ord_qty, Length: 585446, dtype: int64

# %%
plot_con_cat(group20457)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4364\1481476353.py:23: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data['sales_chan_name'] == sales_chan_name[i]][cols[8]], color=colors[i], shade=True, ec='black',label=sales_chan_name[i],alpha=alphas[i])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4364\1481476353.py:23: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data['sales_chan_name'] == sales_chan_name[i]][cols[8]], color=colors[i], shade=True, ec='black',label=sales_chan_name[i],alpha=alphas[i])

# %%
data_test = data_train_new.loc[:,'sales_region_code']
data_test
# Out:
# 0         104
# 1         104
# 2         104
# 3         104
# 4         104
#          ...
# 585441    103
# 585442    103
# 585443    102
# 585444    102
# 585445    105
# Name: sales_region_code, Length: 585446, dtype: int64
